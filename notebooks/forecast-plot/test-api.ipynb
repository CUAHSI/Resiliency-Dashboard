# %%
import json
import requests

# %%
query = 'https://localhost/api/timeseries/nwm-historical?reach_id=5984765&start_date=2024-10-01&end_date=2024-12-31&offset=3'

# %%
res = requests.get(query, verify=False)
# Out:
# /Users/castro/Documents/work/community-resilience/notebooks/forecast-plot/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
response_json = res.text

# %%
dat = json.loads(response_json)

# %%
dat
# Out:
# {'2024-10-01 00:00:00': 0.1099999994039535,
#  '2024-10-01 01:00:00': 0.1099999994039535,
#  '2024-10-01 02:00:00': 0.1099999994039535,
#  '2024-10-01 03:00:00': 0.1099999994039535,
#  '2024-10-01 04:00:00': 0.1099999994039535,
#  '2024-10-01 05:00:00': 0.1099999994039535,
#  '2024-10-01 06:00:00': 0.1099999994039535,
#  '2024-10-01 07:00:00': 0.1099999994039535,
#  '2024-10-01 08:00:00': 0.1099999994039535,
#  '2024-10-01 09:00:00': 0.1099999994039535,
#  '2024-10-01 10:00:00': 0.1099999994039535,
#  '2024-10-01 11:00:00': 0.1099999994039535,
#  '2024-10-01 12:00:00': 0.1099999994039535,
#  '2024-10-01 13:00:00': 0.1099999994039535,
#  '2024-10-01 14:00:00': 0.1099999994039535,
#  '2024-10-01 15:00:00': 0.1099999994039535,
#  '2024-10-01 16:00:00': 0.1099999994039535,
#  '2024-10-01 17:00:00': 0.1099999994039535,
#  '2024-10-01 18:00:00': 0.1099999994039535,
#  '2024-10-01 19:00:00': 0.1099999994039535,
#  '2024-10-01 20:00:00': 0.1099999994039535,
# ...
